# %% [markdown]
# <a href="https://colab.research.google.com/github/solivagvs/Stat-554/blob/main/testfile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
3 ** 9
# Out:
# 19683

# %%
3 - 9
# Out:
# -6
